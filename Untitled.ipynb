# %%
from map.WorldMap import WorldMap
from helper import *
import torch
import matplotlib.pyplot as plt
import numpy as np
from tqdm import trange

# %%
np.random.seed(205)

device = "cuda"
map_generator_params = {
    "size": 2**10 + 1,  # Must be 2^n + 1 for diamond-square
    "scale": 1.0,
    "roughness": 0.55,
    "river_count": 5,
}

growth_factor = np.asarray([
    [2, 1.5, 1.0],  # preference
    [1.5, 2.0, 1.0],  # distance
])

city_params = {
    "max_radius": 500,
    "max_road_radius" : 15,
    "growth_factor": growth_factor,
    "city_init_factor" : 1.,
    
}

world_map = WorldMap(map_generator_params = map_generator_params, device = device, city_params=city_params, city_count=8, filename=None)

world_map.plotter.plot()
#world_map.save()
# Out:
# City 1: Population = 0, Area =  0.00 km2
# City 2: Population = 0, Area =  0.00 km2
# City 3: Population = 0, Area =  0.00 km2
# City 4: Population = 0, Area =  0.00 km2
# City 5: Population = 0, Area =  0.00 km2
# City 6: Population = 0, Area =  0.00 km2

# %%
for i in range(8):
    for t in trange(100):
        grow_random_all(world_map)

    world_map.plotter.plot()
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [01:14<00:00,  1.35it/s]
# City 1: Population = 374, Area =  0.37 km2
# City 2: Population = 496, Area =  0.50 km2
# City 3: Population = 487, Area =  0.49 km2
# City 4: Population = 365, Area =  0.37 km2
# City 5: Population = 477, Area =  0.48 km2
# City 6: Population = 445, Area =  0.45 km2
#  29%|█████████████████████████████████████████▊                                                                                                      | 29/100 [00:24<01:03,  1.12it/s]

# %%
ds = world_map.maps["directional_slope"]
x = plt.hist(ds.flatten(), bins=100)
